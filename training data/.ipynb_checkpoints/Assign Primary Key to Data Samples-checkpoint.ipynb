# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("processed_audio_sample_scoring.xlsx")

# %%
import uuid

def generate_unique_key():
    return str(uuid.uuid4())

# Example usage:
unique_key = generate_unique_key()
print(unique_key)
# Out:
# a788895e-213d-43df-91f8-bebfd4424e3d

# %%
df['primary key'] = df.apply(lambda x: generate_unique_key(), axis=1)

# %%
df
# Out:
#      Unnamed: 0                           Record Audio Name  Content  Pronun  \
# 0             0  audio_beb45dff-f264-43c5-b051-61dab6a3b2a1       18      11
# 1             1  audio_f86da9b5-9ed2-4153-9508-e59448e7d8bc       70      53
# 2             2  audio_0e7cded9-1569-4202-98f8-59f88384437b       54      40
# 3             3  audio_08bf8a53-1e31-4d82-8979-b53a14baa196       28      14
# 4             4  audio_a3b474a9-3b8e-4533-aa95-0cda51f1395d       16      11
# ..          ...                                         ...      ...     ...
# 405         424  audio_384c1f79-8577-4663-bdba-33245a5d85ea       65      40
# 406         425  audio_7ea181b4-ac85-4269-a3a5-2ef56bd6bb63       10      10
# 407         426  audio_d3528ab8-9377-4290-a7b4-895a5273386e       10      10
# 408         427  audio_26b0ab19-ac6f-433b-95b2-3a48bad12aae       46      26
# 409         428  audio_257c1a74-153f-457e-8a34-1a514c689955       16      10
#
#      Fluency  feature_vector                           primary key
# 0         25             NaN  e8164bd2-334b-4d80-a775-df8321fcccfa
# 1         64             NaN  234f2f41-82a2-4420-8b5e-39fd0a45e02a
# 2         51             NaN  0882b978-d9b6-488c-826d-f65edaa0c69e
# 3         36             NaN  7f773fc0-f0d2-4327-a09c-abc9706ca3ea
# 4         25             NaN  ed82c27b-4c29-4fa6-b008-dd7e40fe01cd
# ..       ...             ...                                   ...
# 405       54             NaN  845b18b5-58a4-49eb-8dab-d3d75218b20a
# 406       10             NaN  c6392772-a649-403a-8e44-c8774f60411f
# 407       21             NaN  146fa47b-aa1c-499d-9469-afdc0cf67549
# 408       39             NaN  06f8ff29-6934-4fe0-a681-73da175f5adf
# 409       27             NaN  4a8868f6-c1b5-4d17-847f-c36e72c70c3e
#
# [410 rows x 7 columns]

# %%
df.to_excel("processed_audio_sample_scoring.xlsx")
